# %% [markdown]
# ![imagen](../../imagenes/ejercicios.png)
#
# # Ejercicio SQL con Pandas
#
# Vamos a repetir el mismo ejercicio que vimos para SQL pero con Pandas, para que veamos la potencia que tiene lo que estamos haciendo.
#
# Para este ejercicio usaremos una base de datos del FIFA 20. **Asegúrante que tienes el CSV "FIFA20.csv" en la misma carpeta donde está este Notebook**. Realiza los siguientes apartados:
#
# 1. Obtén una tabla con todos los campos
# 2. Obtén una tabla con los campos "short_name", "club", "team_position"
# 3. Obtén la misma tabla que el apartado anterior, pero en este caso renombrando los campos al castellano.
# 4. ¿Cuáles son todos los "team_position" diferentes?
# 5. ¿Cuáles son todos los "team_position" y "preferred_foot" diferentes?
# 6. ¿Cuáles son los jugadores diestros? ("preferred_foot" = "Right")
# 7. Obtén una tabla con los jugadores influencers
# 8. Obtén una tabla con los extremos izquierda ('team_position' = 'LW') influencers
# 9. Obtén una tabla con los jugadores cuyo nombre empieze por "W" y tenga una puntuación ('overall') mayor de 80 puntos.
#   1. ¿Y si ponemos el límite de la puntuación en mayor de 90 puntos?
# 10. Saca una tabla con los jugadores del Real Madrid, que NO sean diestros y tengan un potencial superior a 85
# 11. ¿Cuál es el jugador con la puntuación ('overall') más alta?
# 12. ¿Cuál es la media del valor (value_eur) de todos los jugadores, en millones de euros, sabiendo que las unidades del valor de la tabla son euros?
# 13. ¿Cuál es la media del salario por equipo?
# 14. Calcula la máxima puntuación ('overall') por "'preferred_foot'
#
# **NOTA**: se recomienda añadir un `LIMIT 5` en la mayoría de apartados para evitar grandes outputs de las queries.

# %%
# Importamos paquetes
import pandas as pd
import numpy as np

# Leemos datos de un CSV
df = pd.read_csv('FIFA20.csv')
df.head()
# Out:
#           short_name                            long_name         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior  1992-02-05
# 3           J. Oblak                            Jan Oblak  1993-01-07
# 4          E. Hazard                          Eden Hazard  1991-01-07
#
#                   club  overall  potential  value_eur  wage_eur team_position  \
# 0         FC Barcelona       94         94   95500000    565000            RW
# 1             Juventus       93         93   58500000    405000            LW
# 2  Paris Saint-Germain       92         92  105500000    290000           CAM
# 3      Atlético Madrid       91         93   77500000    125000            GK
# 4          Real Madrid       91         91   90000000    470000            LW
#
#   preferred_foot  influencer
# 0           Left        True
# 1          Right        True
# 2          Right        True
# 3          Right       False
# 4          Right        True

# %%
# 1. Obten una tabla con todos los campos
df
# Out:
#               short_name                            long_name         dob  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini  1987-06-24
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05
# 2              Neymar Jr        Neymar da Silva Santos Junior  1992-02-05
# 3               J. Oblak                            Jan Oblak  1993-01-07
# 4              E. Hazard                          Eden Hazard  1991-01-07
# ...                  ...                                  ...         ...
# 18273         Shao Shuai                                   邵帅  1997-03-10
# 18274       Xiao Mingjie                         Mingjie Xiao  1997-01-01
# 18275          Zhang Wei                                   张威  2000-05-16
# 18276       Wang Haijian                                  汪海健  2000-08-02
# 18277         Pan Ximing                                  潘喜明  1993-01-11
#
#                                 club  overall  potential  value_eur  wage_eur  \
# 0                       FC Barcelona       94         94   95500000    565000
# 1                           Juventus       93         93   58500000    405000
# 2                Paris Saint-Germain       92         92  105500000    290000
# 3                    Atlético Madrid       91         93   77500000    125000
# 4                        Real Madrid       91         91   90000000    470000
# ...                              ...      ...        ...        ...       ...
# 18273               Beijing Renhe FC       48         56      40000      2000
# 18274               Shanghai SIPG FC       48         56      40000      2000
# 18275         Hebei China Fortune FC       48         56      40000      1000
# 18276  Shanghai Greenland Shenhua FC       48         54      40000      1000
# 18277         Hebei China Fortune FC       48         51      40000      2000
#
#       team_position preferred_foot  influencer
# 0                RW           Left        True
# 1                LW          Right        True
# 2               CAM          Right        True
# 3                GK          Right       False
# 4                LW          Right        True
# ...             ...            ...         ...
# 18273           RES          Right       False
# 18274           SUB          Right       False
# 18275           SUB          Right       False
# 18276           SUB          Right       False
# 18277           SUB          Right       False
#
# [18278 rows x 11 columns]

# %%
# 2. Obtén una tabla con los campos "short_name", "club", "team_position"
df[['short_name', 'club', 'team_position']]
# Out:
#               short_name                           club team_position
# 0               L. Messi                   FC Barcelona            RW
# 1      Cristiano Ronaldo                       Juventus            LW
# 2              Neymar Jr            Paris Saint-Germain           CAM
# 3               J. Oblak                Atlético Madrid            GK
# 4              E. Hazard                    Real Madrid            LW
# ...                  ...                            ...           ...
# 18273         Shao Shuai               Beijing Renhe FC           RES
# 18274       Xiao Mingjie               Shanghai SIPG FC           SUB
# 18275          Zhang Wei         Hebei China Fortune FC           SUB
# 18276       Wang Haijian  Shanghai Greenland Shenhua FC           SUB
# 18277         Pan Ximing         Hebei China Fortune FC           SUB
#
# [18278 rows x 3 columns]

# %%
# 3. Obtén la misma tabla que el apartado anterior, pero en este caso renombrando los campos al castellano.
df[['short_name', 'club', 'team_position']].rename({'short_name': 'nombre_corto', 'club': 'equipo', 'team_position': 'posicion_equipo'}, axis=1)
# Out:
#             nombre_corto                         equipo posicion_equipo
# 0               L. Messi                   FC Barcelona              RW
# 1      Cristiano Ronaldo                       Juventus              LW
# 2              Neymar Jr            Paris Saint-Germain             CAM
# 3               J. Oblak                Atlético Madrid              GK
# 4              E. Hazard                    Real Madrid              LW
# ...                  ...                            ...             ...
# 18273         Shao Shuai               Beijing Renhe FC             RES
# 18274       Xiao Mingjie               Shanghai SIPG FC             SUB
# 18275          Zhang Wei         Hebei China Fortune FC             SUB
# 18276       Wang Haijian  Shanghai Greenland Shenhua FC             SUB
# 18277         Pan Ximing         Hebei China Fortune FC             SUB
#
# [18278 rows x 3 columns]

# %%
# 4. ¿Cuáles son todos los "team_position" diferentes? PAra este deberás
df['team_position'].drop_duplicates()
# Out:
# 0       RW
# 1       LW
# 2      CAM
# 3       GK
# 5      RCM
# 7      LCB
# 12      ST
# 21     CDM
# 24     LDM
# 27      RM
# 29     RCB
# 33     LCM
# 38      LM
# 46      CF
# 48     SUB
# 51      LB
# 54      LS
# 61      RB
# 78     RDM
# 93     RES
# 95     RAM
# 104     RS
# 109     RF
# 123     CM
# 126     CB
# 259     LF
# 306    LAM
# 327    NaN
# 476    RWB
# 483    LWB
# Name: team_position, dtype: object

# %%
# 5. ¿Cuáles son todos los "team_position" y "preferred_foot" diferentes?
df[['team_position', 'preferred_foot']].drop_duplicates()
# Out:
#      team_position preferred_foot
# 0               RW           Left
# 1               LW          Right
# 2              CAM          Right
# 3               GK          Right
# 5              RCM          Right
# 7              LCB          Right
# 10              RW          Right
# 12              ST          Right
# 16             LCB           Left
# 21             CDM          Right
# 22              LW           Left
# 24             LDM          Right
# 25              GK           Left
# 27              RM          Right
# 29             RCB          Right
# 33             LCM           Left
# 36             LCM          Right
# 38              LM          Right
# 46              CF          Right
# 48             SUB          Right
# 51              LB           Left
# 54              LS          Right
# 55             SUB           Left
# 61              RB          Right
# 78             RDM          Right
# 89              LS           Left
# 93             RES          Right
# 95             RAM           Left
# 104             RS           Left
# 109             RF           Left
# 121             RM           Left
# 123             CM          Right
# 126             CB          Right
# 135            CAM           Left
# 149            RCM           Left
# 152             ST           Left
# 176             LM           Left
# 201            RES           Left
# 222            LDM           Left
# 230             RS          Right
# 231             CB           Left
# 259             LF           Left
# 306            LAM          Right
# 327            NaN          Right
# 340            LAM           Left
# 374             CM           Left
# 394            CDM           Left
# 408            NaN           Left
# 476            RWB          Right
# 483            LWB           Left
# 557            RDM           Left
# 618            LWB          Right
# 745            RCB           Left
# 832            RAM          Right
# 1011            LF          Right
# 1060            RF          Right
# 1238            LB          Right
# 1410            CF           Left
# 7406            RB           Left
# 9046           RWB           Left

# %%
# 6. ¿Cuáles son los jugadores diestros? ("preferred_foot" = "Right")
df[df["preferred_foot"] == "Right"]
# Out:
#               short_name                            long_name         dob  \
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05
# 2              Neymar Jr        Neymar da Silva Santos Junior  1992-02-05
# 3               J. Oblak                            Jan Oblak  1993-01-07
# 4              E. Hazard                          Eden Hazard  1991-01-07
# 5           K. De Bruyne                      Kevin De Bruyne  1991-06-28
# ...                  ...                                  ...         ...
# 18273         Shao Shuai                                   邵帅  1997-03-10
# 18274       Xiao Mingjie                         Mingjie Xiao  1997-01-01
# 18275          Zhang Wei                                   张威  2000-05-16
# 18276       Wang Haijian                                  汪海健  2000-08-02
# 18277         Pan Ximing                                  潘喜明  1993-01-11
#
#                                 club  overall  potential  value_eur  wage_eur  \
# 1                           Juventus       93         93   58500000    405000
# 2                Paris Saint-Germain       92         92  105500000    290000
# 3                    Atlético Madrid       91         93   77500000    125000
# 4                        Real Madrid       91         91   90000000    470000
# 5                    Manchester City       91         91   90000000    370000
# ...                              ...      ...        ...        ...       ...
# 18273               Beijing Renhe FC       48         56      40000      2000
# 18274               Shanghai SIPG FC       48         56      40000      2000
# 18275         Hebei China Fortune FC       48         56      40000      1000
# 18276  Shanghai Greenland Shenhua FC       48         54      40000      1000
# 18277         Hebei China Fortune FC       48         51      40000      2000
#
#       team_position preferred_foot  influencer
# 1                LW          Right        True
# 2               CAM          Right        True
# 3                GK          Right       False
# 4                LW          Right        True
# 5               RCM          Right        True
# ...             ...            ...         ...
# 18273           RES          Right       False
# 18274           SUB          Right       False
# 18275           SUB          Right       False
# 18276           SUB          Right       False
# 18277           SUB          Right       False
#
# [13960 rows x 11 columns]

# %%
# 7. Obtén una tabla con los jugadores influencers
df[df['influencer'] == True]
# Out:
#              short_name                            long_name         dob  \
# 0              L. Messi       Lionel Andrés Messi Cuccittini  1987-06-24
# 1     Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05
# 2             Neymar Jr        Neymar da Silva Santos Junior  1992-02-05
# 4             E. Hazard                          Eden Hazard  1991-01-07
# 5          K. De Bruyne                      Kevin De Bruyne  1991-06-28
# 8             L. Modrić                          Luka Modrić  1985-09-09
# 14               De Gea                David De Gea Quintana  1990-11-07
# 16         G. Chiellini                    Giorgio Chiellini  1984-08-14
# 17            S. Agüero    Sergio Leonel Agüero del Castillo  1988-06-02
# 18         Sergio Ramos                  Sergio Ramos García  1986-03-30
# 19            L. Suárez             Luis Alberto Suárez Díaz  1987-01-24
# 20       R. Lewandowski                   Robert Lewandowski  1988-08-21
# 21      Sergio Busquets             Sergio Busquets i Burgos  1988-07-16
# 22         A. Griezmann                    Antoine Griezmann  1991-03-21
# 24             P. Pogba                           Paul Pogba  1993-03-15
# 28          T. Courtois                     Thibaut Courtois  1992-05-11
# 29                Piqué                Gerard Piqué Bernabéu  1987-02-02
# 31             M. Neuer                         Manuel Neuer  1986-03-27
# 32            H. Lloris                          Hugo Lloris  1986-12-26
# 33          David Silva            David Josué Jiménez Silva  1986-01-08
# 34            E. Cavani         Edinson Roberto Cavani Gómez  1987-02-14
# 36             T. Kroos                           Toni Kroos  1990-01-04
# 37              M. Reus                           Marco Reus  1989-05-31
# 45         Thiago Silva             Thiago Emiliano da Silva  1984-09-22
# 46           K. Benzema                        Karim Benzema  1987-12-19
# 49           M. Hummels                        Mats  Hummels  1988-12-16
# 64           I. Rakitić                         Ivan Rakitić  1988-03-10
# 66          A. Di María      Ángel Fabián Di María Hernández  1988-02-14
# 70            T. Müller                        Thomas Müller  1989-09-13
# 92             D. Alaba               David Olatukunbo Alaba  1992-06-24
# 96       Z. Ibrahimović                   Zlatan Ibrahimović  1981-10-03
# 98           G. Higuaín              Gonzalo Gerardo Higuaín  1987-12-10
# 100             G. Bale                    Gareth Frank Bale  1989-07-16
# 101             Marcelo       Marcelo Vieira da Silva Júnior  1988-05-12
# 106        J. Rodríguez          James David Rodríguez Rubio  1991-07-12
# 128                Pepe         Képler Laveran Lima Ferreira  1983-02-26
# 135             M. Özil                           Mesut Özil  1988-10-15
# 142            A. Vidal                         Arturo Vidal  1987-05-22
# 143          J. Boateng                       Jérôme Boateng  1988-09-03
# 200           G. Buffon                     Gianluigi Buffon  1978-01-28
# 201            Casillas              Iker Casillas Fernández  1981-05-20
# 203          V. Kompany                      Vincent Kompany  1986-04-10
# 214         Diego Costa                 Diego da Silva Costa  1988-10-07
# 216          David Luiz           David Luiz Moreira Marinho  1987-04-22
# 270            M. Götze                          Mario Götze  1992-06-03
# 301          A. Sánchez     Alexis Alejandro Sánchez Sánchez  1988-12-19
# 304        M. Balotelli             Mario  Barwuah Balotelli  1990-08-12
# 375       Cesc Fàbregas            Francesc Fàbregas i Soler  1987-05-04
# 488           W. Rooney                    Wayne Mark Rooney  1985-10-24
# 491       J. Mascherano          Javier Alejandro Mascherano  1984-06-08
# 532                Hulk            Givanildo Vieira de Souza  1986-07-25
# 1424  B. Schweinsteiger               Bastian Schweinsteiger  1984-08-01
#
#                         club  overall  potential  value_eur  wage_eur  \
# 0               FC Barcelona       94         94   95500000    565000
# 1                   Juventus       93         93   58500000    405000
# 2        Paris Saint-Germain       92         92  105500000    290000
# 4                Real Madrid       91         91   90000000    470000
# 5            Manchester City       91         91   90000000    370000
# 8                Real Madrid       90         90   45000000    340000
# 14         Manchester United       89         90   56000000    205000
# 16                  Juventus       89         89   24500000    215000
# 17           Manchester City       89         89   60000000    300000
# 18               Real Madrid       89         89   31500000    300000
# 19              FC Barcelona       89         89   53000000    355000
# 20         FC Bayern München       89         89   64500000    235000
# 21              FC Barcelona       89         89   55000000    300000
# 22              FC Barcelona       89         89   69000000    370000
# 24         Manchester United       88         91   72500000    250000
# 28               Real Madrid       88         89   48000000    235000
# 29              FC Barcelona       88         88   38000000    285000
# 31         FC Bayern München       88         88   32000000    155000
# 32         Tottenham Hotspur       88         88   36000000    150000
# 33           Manchester City       88         88   36000000    265000
# 34       Paris Saint-Germain       88         88   47000000    195000
# 36               Real Madrid       88         88   57000000    330000
# 37         Borussia Dortmund       88         88   56000000    170000
# 45       Paris Saint-Germain       87         87   18500000    135000
# 46               Real Madrid       87         87   45000000    285000
# 49         Borussia Dortmund       87         87   41000000    130000
# 64              FC Barcelona       86         86   38000000    245000
# 66       Paris Saint-Germain       86         86   39000000    150000
# 70         FC Bayern München       86         86   43500000    170000
# 92         FC Bayern München       85         86   38000000    135000
# 96                 LA Galaxy       85         85   14000000     15000
# 98                  Juventus       85         85   34500000    175000
# 100              Real Madrid       85         85   37500000    250000
# 101              Real Madrid       85         85   28000000    205000
# 106              Real Madrid       85         85   40500000    225000
# 128                 FC Porto       84         84    6500000     16000
# 135                  Arsenal       84         84   29500000    125000
# 142             FC Barcelona       84         84   23500000    205000
# 143        FC Bayern München       84         84   25000000    125000
# 200                 Juventus       83         83    2600000     58000
# 201                 FC Porto       83         83    2600000     11000
# 203           RSC Anderlecht       83         83   12000000     31000
# 214          Atlético Madrid       83         83   25000000     80000
# 216                  Arsenal       83         83   16500000    105000
# 270        Borussia Dortmund       82         83   26000000     98000
# 301        Manchester United       82         82   21000000    150000
# 304                  Brescia       82         82   23000000     27000
# 375                AS Monaco       81         81   13500000     50000
# 488                DC United       80         80    9500000     13000
# 491   Hebei China Fortune FC       80         80    4700000     13000
# 532         Shanghai SIPG FC       80         80   11500000     23000
# 1424            Chicago Fire       76         76    2900000      8000
#
#      team_position preferred_foot  influencer
# 0               RW           Left        True
# 1               LW          Right        True
# 2              CAM          Right        True
# 4               LW          Right        True
# 5              RCM          Right        True
# 8              RCM          Right        True
# 14              GK          Right        True
# 16             LCB           Left        True
# 17              ST          Right        True
# 18             LCB          Right        True
# 19              ST          Right        True
# 20              ST          Right        True
# 21             CDM          Right        True
# 22              LW           Left        True
# 24             LDM          Right        True
# 28              GK           Left        True
# 29             RCB          Right        True
# 31              GK          Right        True
# 32              GK           Left        True
# 33             LCM           Left        True
# 34              ST          Right        True
# 36             LCM          Right        True
# 37             CAM          Right        True
# 45             LCB          Right        True
# 46              CF          Right        True
# 49             LCB          Right        True
# 64             RCM          Right        True
# 66              LW           Left        True
# 70             SUB          Right        True
# 92              LB           Left        True
# 96              ST          Right        True
# 98             SUB          Right        True
# 100            SUB           Left        True
# 101             LB           Left        True
# 106            SUB           Left        True
# 128            RCB          Right        True
# 135            CAM           Left        True
# 142            SUB          Right        True
# 143            SUB          Right        True
# 200            SUB          Right        True
# 201            RES           Left        True
# 203            LCB          Right        True
# 214            SUB          Right        True
# 216            LCB          Right        True
# 270            SUB          Right        True
# 301            SUB          Right        True
# 304             RS          Right        True
# 375            LCM          Right        True
# 488             ST          Right        True
# 491            CDM          Right        True
# 532             RW           Left        True
# 1424           RCB          Right        True

# %%
# 8. Obtén una tabla con los extremos izquierda ('team_position' = 'LW') influencers
df[(df["team_position"] == "LW") & (df["influencer"] == True)]
# Out:
#            short_name                            long_name         dob  \
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05
# 4           E. Hazard                          Eden Hazard  1991-01-07
# 22       A. Griezmann                    Antoine Griezmann  1991-03-21
# 66        A. Di María      Ángel Fabián Di María Hernández  1988-02-14
#
#                    club  overall  potential  value_eur  wage_eur  \
# 1              Juventus       93         93   58500000    405000
# 4           Real Madrid       91         91   90000000    470000
# 22         FC Barcelona       89         89   69000000    370000
# 66  Paris Saint-Germain       86         86   39000000    150000
#
#    team_position preferred_foot  influencer
# 1             LW          Right        True
# 4             LW          Right        True
# 22            LW           Left        True
# 66            LW           Left        True

# %%
# 9. Obtén una tabla con los jugadores cuyo nombre empieze por "W" y tenga una puntuación ('overall') mayor de 80 puntos
df[(df['long_name'].apply(lambda x: x[0] == "W")) & (df['overall'] > 80)]
# Out:
#            short_name                  long_name         dob            club  \
# 60        W. Szczęsny         Wojciech  Szczęsny  1990-04-18        Juventus
# 185           W. Zaha              Wilfried Zaha  1992-11-10  Crystal Palace
# 189  William Carvalho  William Silva de Carvalho  1992-04-07      Real Betis
# 230     W. Ben Yedder          Wissam Ben Yedder  1990-08-12       AS Monaco
# 273      Willian José      Willian José da Silva  1991-11-23   Real Sociedad
# 298           Willian    Willian Borges da Silva  1988-08-09         Chelsea
# 352          W. Orban                Willi Orban  1992-11-03      RB Leipzig
# 368       W. Weghorst              Wout Weghorst  1992-08-07   VfL Wolfsburg
#
#      overall  potential  value_eur  wage_eur team_position preferred_foot  \
# 60        86         88   37500000    135000            GK          Right
# 185       83         85   32000000     89000            LS          Right
# 189       83         85   27500000     35000           CDM          Right
# 230       83         83   27000000     67000            RS          Right
# 273       82         83   26000000     44000            ST          Right
# 298       82         82   21000000    140000           SUB          Right
# 352       81         83   19000000     57000           LCB          Right
# 368       81         82   21000000     62000            ST          Right
#
#      influencer
# 60        False
# 185       False
# 189       False
# 230       False
# 273       False
# 298       False
# 352       False
# 368       False

# %%
# 9. ¿Y si en lugar de 80, buscamos que la puntuación sea mayor de 90?
df[(df['long_name'].apply(lambda x: x[0] == "W")) & (df['overall'] > 90)]
# Out:
# Empty DataFrame
# Columns: [short_name, long_name, dob, club, overall, potential, value_eur, wage_eur, team_position, preferred_foot, influencer]
# Index: []

# %% [markdown]
# Correcto. Ninguno lo cumple

# %%
# 10. Saca una tabla con los jugadores del Real Madrid, que NO sean diestros y tengan un potencial superior a 85
df[(df['club'] == "Real Madrid") & (df['preferred_foot'] != "Right") & (df['potential'] > 85)]
# Out:
#          short_name                long_name         dob         club  \
# 28      T. Courtois         Thibaut Courtois  1992-05-11  Real Madrid
# 178   Marco Asensio  Marco Asensio Willemsen  1996-01-21  Real Madrid
# 424        F. Mendy            Ferland Mendy  1995-06-08  Real Madrid
# 2652         Brahim              Brahim Díaz  1999-08-03  Real Madrid
# 4757        T. Kubo                    久保 建英  2001-06-04  Real Madrid
#
#       overall  potential  value_eur  wage_eur team_position preferred_foot  \
# 28         88         89   48000000    235000            GK           Left
# 178        83         87   34000000    180000           SUB           Left
# 424        80         86   18000000    115000           SUB           Left
# 2652       73         86    7500000     58000           RES           Left
# 4757       70         87    3700000     21000           RES           Left
#
#       influencer
# 28          True
# 178        False
# 424        False
# 2652       False
# 4757       False

# %%
# 11. ¿Cuál es el jugador con la puntuación ('overall') más alta?
df.sort_values(by='overall', ascending = False).iloc[:1]
# Out:
#   short_name                       long_name         dob          club  \
# 0   L. Messi  Lionel Andrés Messi Cuccittini  1987-06-24  FC Barcelona
#
#    overall  potential  value_eur  wage_eur team_position preferred_foot  \
# 0       94         94   95500000    565000            RW           Left
#
#    influencer
# 0        True

# %%
df[df['overall'] == df['overall'].max()]
# Out:
#   short_name                       long_name         dob          club  \
# 0   L. Messi  Lionel Andrés Messi Cuccittini  1987-06-24  FC Barcelona
#
#    overall  potential  value_eur  wage_eur team_position preferred_foot  \
# 0       94         94   95500000    565000            RW           Left
#
#    influencer   aux  mask
# 0        True  True  True

# %%
# 12. ¿Cuál es la media del valor (value_eur) de todos los jugadores, en millones de euros, sabiendo que las unidades del valor de la tabla son euros?
df['value_eur'].mean()
# Out:
# 2484037.640879746

# %%
# 13. ¿Cuál es la media del salario por equipo? Ordena el resultado de mayor a menor salario
df.groupby("club").agg({'wage_eur': np.mean}).sort_values('wage_eur', ascending=False)
# Out:
#                         wage_eur
# club
# Real Madrid        162242.424242
# FC Barcelona       150000.000000
# Manchester City    120727.272727
# Juventus           113636.363636
# FC Bayern München  109391.304348
# ...                          ...
# Iceland                 0.000000
# India                   0.000000
# Bolivia                 0.000000
# Wales                   0.000000
# Sweden                  0.000000
#
# [698 rows x 1 columns]

# %%
# 14. Calcula la máxima puntuación ('overall') por club. Ordena el resultado de menor a mayor puntuación
df.groupby("club").agg({'overall': np.max}).sort_values('overall', ascending = False)
# df.groupby("club").agg({'overall': [np.max, np.min]}).sort_values(('overall', 'amax'), ascending = False)
# Out:
#                      overall
# club
# FC Barcelona              94
# Juventus                  93
# Paris Saint-Germain       92
# Manchester City           91
# Real Madrid               91
# ...                      ...
# Sligo Rovers              62
# Finn Harps                60
# Seongnam FC               60
# UCD AFC                   58
# Śląsk Wrocław             57
#
# [698 rows x 1 columns]
